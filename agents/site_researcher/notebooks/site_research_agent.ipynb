# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os
from sqlalchemy import create_engine

from dotenv import load_dotenv
from IPython.display import Image, display, HTML, Markdown

from src.agents import site_researcher_graph
from src.utils import format_site_details

# %%
load_dotenv()

connection_string = (
    "postgresql://{user}:{password}@{host}:{port}/{db}".format(
        user=os.getenv("DB_USER"),
        password=os.getenv("DB_PASSWORD"),
        host=os.getenv("DB_HOST"),
        port=os.getenv("DB_PORT"),
        db=os.getenv("DB_NAME"),
    )
)
engine = create_engine(connection_string)

# %%
display(Image(site_researcher_graph.get_graph().draw_mermaid_png()))

# %%
site_info = site_researcher_graph.invoke({
    "site_name": "Raná",
    "site_details": format_site_details("Raná", "CZ", engine)
    })

# %%
print(site_info["tags"])
# Out:
# ['flats', 'official', 'Raná', 'České Středohoří', 'Louny']

# %%
print(f"Skill level: {site_info['skill_level']}\nReason: {site_info['skill_level_description']}")
# Out:
# Skill level: Beginner
# Reason: The site features straightforward takeoffs and large landing areas, making it suitable for beginners. It is a popular training hill used by schools and is ideal for novice pilots to practice ridge soaring in calm conditions.

# %%
print("More info:")
for link in site_info["official_websites"]:
    print(f"{link['url']}: {link['description']}")
# Out:
# More info:
# http://www.rana-paragliding.cz: Official website of Paragliding Club Raná (Paragliding klub Raná z.s.), providing information for pilots, managing the take-off sites, and outlining operating rules and donation options for site maintenance. [4, 11, 12, 14, 16]
# http://www.zakladni-skola-letani.cz: Official website of Základní škola létání (Basic Flight School), offering paragliding courses, tandem flights, and other services at the Raná site. [3, 5, 7, 10]
# http://www.paragliding.cz: Official website for Mistral Paragliding, an authorized pilot training center that provides paragliding courses, tandem flights, and other services with a base at Raná. [13, 15]

# %%
HTML(site_info["description"])
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>Paragliding Site Guide: Raná (CZ)</title>
# </head>
# <body>
#     <article>
#         <h1>Paragliding Site Guide: Raná, Czech Republic</h1>
#
#         <section id="overview">
#             <h2>Overview</h2>
#             <p>
#                 Welcome to Raná, one of the Czech Republic's most renowned and beloved flying sites. Nestled in the beautiful České Středohoří protected landscape, this official site is managed by the dedicated Paragliding klub Raná. The centerpiece is the long, elegant Raná hill, a national nature reserve that offers reliable conditions and fantastic flying opportunities for pilots of all ambitions.
#             </p>
#             <p>
# ...

# %%
Markdown(site_info["risk_report"])
# Out:
# ## Navigating the Skies of Raná: A Synthesis of Site-Specific Risks and Limitations
#
# Paragliding at the renowned Raná site in the Czech Republic offers pilots breathtaking views and varied flying conditions. However, a thorough understanding of the area's unique risks and limitations is crucial for a safe flight. This document synthesizes credible, up-to-date information gathered from various online sources to provide a verifiable overview of site-specific hazards and regulations.
#
# **Weather-Related Risks:**
#
# Pilots should be particularly mindful of specific local weather phenomena at Raná. In stronger wind conditions, accelerated airflow can be expected in the saddle area and along the sides of the hill. Furthermore, when the wind is from the east to northeast, there is a significant risk of lee-side turbulence behind the main peak. This can create dangerous flying conditions, especially for pilots attempting to top-land.
#
# ...
