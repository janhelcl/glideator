# %%
from browser_use import Agent, ChatGoogle, ChatGroq
from dotenv import load_dotenv
load_dotenv()

#llm = ChatGroq(model="qwen/qwen3-32b")

agent = Agent(
    task="Find the link to the meteostation at paragliding takeoff Bassano",
    llm=ChatGoogle(model="gemini-2.5-flash-lite"),
    calculate_cost=True
)
result = await agent.run()

# %%
result.usage
